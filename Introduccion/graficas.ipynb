# %% [markdown]
# # Gráfica de $f(x)=x - 3^{-x}$

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Función cuadrática.
def f(x):
    return x - 3**(-x)
def g(x):
    return x
def h(x):
    return 3**(-x)

# %%
# Valores del eje X que toma el gráfico.
x=np.linspace(-10, 10,100)

# %%
# Graficar ambas funciones.
plt.figure(figsize=(25,15))
plt.plot(x, f(x), color="blue" )
plt.plot(x, g(x), color="red")
plt.plot(x, h(x), color="brown")
plt.xlabel("Eje $x$", color="black")
plt.ylabel("Eje $y$", color="black")
plt.grid(color="gray")
plt.axhline(0, color="black")
plt.axvline(0, color="black")
plt.title("Gráfica de $f(x)=x-3^{-x}$", color="black")
plt.xlim(-10, 10)
plt.ylim(-5, 5)
plt.savefig("output.png") # Guardar gráfico como imágen PNG.
# Mostrarlo.
plt.show()

# %% [markdown]
# Ejercicio 1: Graficar las funciones $x$ y $3^{-x}$ en una sola figura y comentar cómo su resta da origen a la gráfica de $f(x)$.
#
# Ejercicio 2: Agregar título, color, retícula, rótulos a los ejes y aumentar el tamaño de la gráfica.
#
# La gráfica de:
#  $x-3^{-x}$ (gráfica en color azul)
# resulta de hacer la resta de las gráficas de $x$ (color rojo) y $3^{-x}$ (color café).
