# %% [markdown]
# <a href="https://colab.research.google.com/github/AngelaMarin/M-todos-num-ricos-/blob/main/Punto_fijo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Método de iteración de punto fijo para la función:\
# $f(x)=x^3-x-1=0$.\
# Debido a que la función no cumple con el teorema para garantizar un único punto fijo se propone la siguiente transformación:\
# $g(x)=\sqrt{\frac{x+1}{x}}$

# %%
from math import *
import numpy as np
import matplotlib.pyplot as plt

# %%
#Definimos la función
def f(x):
  return x**3-x-1
#Definimos la función a la cual aplicaremos el método
def g(x):
  return ((x+1)/x)**(1/2)

# %%
#Damos el punto inicial y el intervalo
a=1
b=2
p=1

#Guardamos los datos
p0=p
#Damos los valores iniciales para el error y los contadores
tol=0.001 #Solución exacta a 10^-2
nmax=100 #Número maximo de iteraciónes
error=1 #Error inicial
niter=0 #Contador de iteraciones

# %%
#Método de iteración de punto fijo

#Imprimimos el encabezado y la primera linea de la tabla de iteraciones
print("# iter\t\t p \t\t error")
print("{0}\t\t {1:6.3f} \t {2:6.3f} \t ".format(niter, p, error))
#Cliclo iterativo
errores=[] #Lista de errores para graficarlos
while error>tol and niter<nmax :
  p=g(p0)
  error=abs(p-p0)
  niter+=1
  p0=p
  c=error/0.414 #Se normaliza el error **Viendo el valor del error inicial
  errores.append(c) #por cada iteración se va guardando el error normalizado
  print("{0} \t\t {1:6.3f} \t {2:6.3f}".format(niter, p, error))

print("La raíz de la función dada en el intervalo [{0:1.0f}, {1:1.0f}] es {2:6.3f}".format(a, b, p))
# Out:
# # iter		 p 		 error
# 0		  1.000 	  1.000
# 1 		  1.414 	  0.414
# 2 		  1.307 	  0.108
# 3 		  1.329 	  0.022
# 4 		  1.324 	  0.005
# 5 		  1.325 	  0.001
# 6 		  1.325 	  0.000
# La raíz de la función dada en el intervalo [1, 2] es  1.325

# %% [markdown]
# Graficamos la funcion:\
# $f(x)=x^3-x-1$\
# para graficamente corroborar el resultado del método

# %%
#Valores del eje X que toma la grafica
x=np.linspace(0, 3, 100)

# %%
#Grafica de la función
plt.plot(x, f(x))
plt.title("Gráfica de $f(x)$")
plt.axhline(0, color="black")
plt.axvline(0, color="black")
plt.xlim(0,3)
plt.ylim(-1,3)
plt.xlabel("x")
plt.ylabel("f(x)")
plt.show()

# %% [markdown]
# Por último graficamos los errores para ver su convergencia

# %%
plt.plot(errores)
plt.title("Gráfica de los errores")
plt.axhline(0,color="black")
plt.axvline(0, color="black")
plt.xlabel("i")
plt.ylabel("e")
plt.show()
